# %%
spark.sql(""" create catalog if not exists resume_batch3  """)

# %%
list_schema= ['staging' ,  'bronze' , 'silver' , 'gold' ]
for schema in list_schema:
    spark.sql(f""" create schema if not exists resume_batch3.{schema}   """)

# %%
spark.sql("""create volume if not exists resume_batch3.staging.source_files""")
